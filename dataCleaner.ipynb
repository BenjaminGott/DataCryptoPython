# %% [markdown]
# File data cleaner

# %% [markdown]
# Dif between Raw and interim

# %% [markdown]
# First, REMOVE the [Current Crypto leaderboard File](<data/raw/Current Crypto leaderboard.csv>)  because it was different from the others.

# %% [markdown]
# Diff between interim and process

# %% [markdown]
# Objectif regroupe all data in one file and add name of crypto for each line

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
extracted_folder = 'data/interim'
dataframes = []
for filename in os.listdir(extracted_folder):
    if filename.endswith('.csv'):
        file_path = os.path.join(extracted_folder, filename)
        dataf = pd.read_csv(file_path)
        
        crypto_name = filename.replace('.csv', '')
        dataf['Crypto Name'] = crypto_name
        dataframes.append(dataf)

df = pd.concat(dataframes, ignore_index=True)
df
# Out:
#               Date      Open      High       Low     Close       Volume  \
# 0       2020-12-25  1.602781  2.918094  1.375262  2.328544  638225549.0
# 1       2020-12-26  2.318946  2.434916  1.582264  1.596896  237653073.0
# 2       2020-12-27  1.597744  1.630781  1.056657  1.062112  183978307.0
# 3       2020-12-28  1.064454  1.254447  1.049051  1.110076  119337529.0
# 4       2020-12-29  1.110460  1.111282  0.761151  0.887798  137916899.0
# ...            ...       ...       ...       ...       ...          ...
# 127740  2022-08-19  0.370240  0.370310  0.331520  0.334590  746159616.0
# 127741  2022-08-20  0.334560  0.342660  0.332180  0.336780  353662208.0
# 127742  2022-08-21  0.336780  0.348340  0.335520  0.344710  313564256.0
# 127743  2022-08-22  0.344870  0.345050  0.331580  0.344150  451145280.0
# 127744  2022-08-23  0.344080  0.344640  0.340190  0.340200  457520864.0
#
#        Currency Crypto Name
# 0           USD       1inch
# 1           USD       1inch
# ...
