# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

extracted_folder = '../data/processed/data_processed.csv'
df = pd.read_csv(extracted_folder)
df
df[df["Crypto Name"]=="bitcoin" ]
df[df["Crypto Name"]=="ethereum" ]
# Out:
#               Date     Open     High      Low    Close     Volume Currency  \
# 104149  2016-03-10    11.20    11.85    11.07    11.75        4.0      USD
# 104150  2016-03-11    11.75    11.95    11.75    11.95      179.0      USD
# 104151  2016-03-12    11.95    13.45    11.95    12.92      833.0      USD
# 104152  2016-03-13    12.92    15.07    12.92    15.07     1295.0      USD
# 104153  2016-03-14    15.07    15.07    11.40    12.50    92183.0      USD
# ...            ...      ...      ...      ...      ...        ...      ...
# 106502  2022-08-19  1846.52  1846.97  1607.60  1609.48  1594321.0      USD
# 106503  2022-08-20  1609.01  1654.84  1525.51  1575.60  1007240.0      USD
# 106504  2022-08-21  1575.61  1644.88  1563.92  1618.25   852071.0      USD
# 106505  2022-08-22  1618.21  1627.13  1531.91  1626.75  1044290.0      USD
# 106506  2022-08-23  1626.70  1636.32  1615.55  1623.24  1053674.0      USD
#
#        Crypto Name
# 104149    ethereum
# 104150    ethereum
# ...

# %% [markdown]
# ## ETHEREUM

# %%
ethereum_data = df[df["Crypto Name"] == "ethereum"]
plt.figure(figsize=(10, 6))
plt.plot(ethereum_data['Date'], ethereum_data['Close'], label='Ethereum')
plt.title('Évolution des prix de clôture - Ethereum')
plt.xlabel('Date')
plt.ylabel('Prix de clôture')
plt.legend()
plt.show()

# %% [markdown]
# L'Ethereum a été créé en 2015 avec, à ses débuts, un prix très faible, mais il s'est fait connaître avec le temps comme une cryptomonnaie très pratique pour la création de contrats intelligents.
